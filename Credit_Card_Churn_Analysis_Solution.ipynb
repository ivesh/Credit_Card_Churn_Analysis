# %% [markdown]
# <a href="https://colab.research.google.com/github/ivesh/Credit_Card_Churn_Analysis/blob/main/Credit_Card_Churn_Analysis_Solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Credit Card Atrrition
#
#
# Credit card attrition a major problem that banks or credit card companies are afraid of. Consider that the business manager of the bank is facing the problem of customer attrition. They want to analyze the data to find out the reason behind this and leverage the same to predict customers who are likely to drop off. This helps them in better planning and to retain the customers before they churn.
#
#
# Data Definition:
#
# **CLIENTNUM**: Client number. Unique identifier for the customer holding the account
#
# **Attrition_Flag**: Internal event (customer activity) variable - if the account is closed then Attrited customer else Existing customer
#
# **Customer_Age**: Demographic variable - Customer's Age in Years
#
# **Gender**: Demographic variable - M=Male, F=Female
#
# **Dependent_count**: Demographic variable - Number of dependents
#
# **Education_Level**: Demographic variable - Educational Qualification of the account holder (example: high school, college graduate, etc.)
#
# **Marital_Status**: Demographic variable - Married, Single, Divorced, Unknown
#
# **Income_Category**: Demographic variable - Annual Income Category of the account holder (< $40K, $40K - 60K, $60K - $80K, $80K-$120K, >
#
# **Card_Category**: Product Variable - Type of Card (Blue, Silver, Gold, Platinum)
#
# **Months_on_book**: Period of relationship with bank
#
# **Total_Relationship_Count**: Total no. of products held by the customer
#
# **Months_Inactive_12_mon**: No. of months inactive in the last 12 months
#
# **Contacts_Count_12_monNo.**: of Contacts in the last 12 months
#
# **Credit_Limit**: Credit Limit on the Credit Card
#
# **Total_Revolving_Bal**: Total Revolving Balance on the Credit Card
#
# **Avg_Open_To_Buy**: Open to Buy Credit Line (Average of last 12 months)
#
# **Total_Amt_Chng_Q4_Q1**: Change in Transaction Amount (Q4 over Q1)
#
# **Total_Trans_Amt**: Total Transaction Amount (Last 12 months)
#
# **Total_Trans_Ct**: Total Transaction Count (Last 12 months)
#
# **Total_Ct_Chng_Q4_Q1**: Change in Transaction Count (Q4 over Q1)
#
# **Avg_Utilization_Ratio**: Average Card Utilization Ratio

# %%
import numpy as np
import pandas as pd

# For visualization
import seaborn as sns
from matplotlib import pyplot as plt

# For over sampling and under sampling of data
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

# For split of the data
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV

# Importing models to work with
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier

# To evaludate the models
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, precision_recall_curve, classification_report

# %%
df = pd.read_csv("/content/credit_card_churn - credit_card_churn.csv.csv")
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# 1              44  ...                       1                      2
# 2              36  ...                       1                      0
# 3              34  ...                       4                      1
# 4              21  ...                       1                      0
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0       12691.0                  777          11914.0                 1.335
# 1        8256.0                  864           7392.0                 1.541
# 2        3418.0                    0           3418.0                 2.594
# 3        3313.0                 2517            796.0                 1.405
# 4        4716.0                    0           4716.0                 2.175
#
#    Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0             1144              42                1.625                  0.061
# 1             1291              33                3.714                  0.105
# 2             1887              20                2.333                  0.000
# 3             1171              20                2.333                  0.760
# 4              816              28                2.500                  0.000
#
# [5 rows x 21 columns]

# %%
#df = pd.read_csv("./Baaging_Boosting_CaseStudy/credit_card_churn_new.csv")
#df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# 1              44  ...                       1                      2
# 2              36  ...                       1                      0
# 3              34  ...                       4                      1
# 4              21  ...                       1                      0
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0       12691.0                  777          11914.0                 1.335
# 1        8256.0                  864           7392.0                 1.541
# 2        3418.0                    0           3418.0                 2.594
# 3        3313.0                 2517            796.0                 1.405
# 4        4716.0                    0           4716.0                 2.175
#
#    Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0             1144              42                1.625                  0.061
# 1             1291              33                3.714                  0.105
# 2             1887              20                2.333                  0.000
# 3             1171              20                2.333                  0.760
# 4              816              28                2.500                  0.000
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Perform Data Health Checks

# %%
df.shape
# Out:
# (10127, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
#  13  Credit_Limit              10127 non-null  float64
#  14  Total_Revolving_Bal       10127 non-null  int64
#  15  Avg_Open_To_Buy           10127 non-null  float64
#  16  Total_Amt_Chng_Q4_Q1      10127 non-null  float64
#  17  Total_Trans_Amt           10127 non-null  int64
#  18  Total_Trans_Ct            10127 non-null  int64
#  19  Total_Ct_Chng_Q4_Q1       10127 non-null  float64
#  20  Avg_Utilization_Ratio     10127 non-null  float64
# dtypes: float64(5), int64(10), object(6)
# memory usage: 1.6+ MB

# %%
df.isnull().sum() / df.shape[1]
# Out:
# CLIENTNUM                   0.0
# Attrition_Flag              0.0
# Customer_Age                0.0
# Gender                      0.0
# Dependent_count             0.0
# Education_Level             0.0
# Marital_Status              0.0
# Income_Category             0.0
# Card_Category               0.0
# Months_on_book              0.0
# Total_Relationship_Count    0.0
# Months_Inactive_12_mon      0.0
# Contacts_Count_12_mon       0.0
# Credit_Limit                0.0
# Total_Revolving_Bal         0.0
# Avg_Open_To_Buy             0.0
# Total_Amt_Chng_Q4_Q1        0.0
# Total_Trans_Amt             0.0
# Total_Trans_Ct              0.0
# Total_Ct_Chng_Q4_Q1         0.0
# Avg_Utilization_Ratio       0.0
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# 50%                    4.000000                2.000000
# 75%                    5.000000                3.000000
# max                    6.000000                6.000000
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# count           10127.000000  10127.000000         10127.000000
# mean                2.455317   8631.953698          1162.814061
# std                 1.106225   9088.776650           814.987335
# min                 0.000000   1438.300000             0.000000
# 25%                 2.000000   2555.000000           359.000000
# 50%                 2.000000   4549.000000          1276.000000
# 75%                 3.000000  11067.500000          1784.000000
# max                 6.000000  34516.000000          2517.000000
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# count     10127.000000          10127.000000     10127.000000    10127.000000
# mean       7469.139637              0.759941      4404.086304       64.858695
# std        9090.685324              0.219207      3397.129254       23.472570
# min           3.000000              0.000000       510.000000       10.000000
# 25%        1324.500000              0.631000      2155.500000       45.000000
# 50%        3474.000000              0.736000      3899.000000       67.000000
# 75%        9859.000000              0.859000      4741.000000       81.000000
# max       34516.000000              3.397000     18484.000000      139.000000
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# count         10127.000000           10127.000000
# mean              0.712222               0.274894
# std               0.238086               0.275691
# min               0.000000               0.000000
# 25%               0.582000               0.023000
# 50%               0.702000               0.176000
# 75%               0.818000               0.503000
# max               3.714000               0.999000

# %% [markdown]
# ## Observations:

# %%
categorical_cols = df.select_dtypes(['object', 'category']).columns.tolist()
numerical_cols = df.select_dtypes(['int64', 'float']).columns.tolist()

# Remove the id variable from numerical cols
numerical_cols.remove('CLIENTNUM')

# Drop the target column from categorical cols
categorical_cols.remove('Attrition_Flag')

# %% [markdown]
# ## Univariate Analysis

# %%
def distribution_plot(data, feature, figsize=(8, 5), bins=10, kde=False):
    f2, ax_hist = plt.subplots(
        nrows=1,  # Number of rows of the subplot grid=1
        figsize=figsize,
    )  # creating the 2 subplots
    sns.histplot(data=data, x=feature, kde=kde, ax=ax_hist, bins=bins)
    ax_hist.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %%
def univariate_categorical_analysis(df, column):

    print("Percentage distribution for", column)
    print(df[column].value_counts(normalize=True) * 100)
    print()

    plt.figure(figsize=(8, 6))
    df[column].value_counts().plot(kind='bar', color='skyblue')
    plt.title("Bar Plot: " + column)
    plt.xlabel(column)
    plt.ylabel("Frequency")
    plt.show()

# %%
for col in numerical_cols:
    distribution_plot(df, col)

# %%
for col in categorical_cols:
    univariate_categorical_analysis(df, col)
# Out:
# Percentage distribution for Gender
# F    52.908068
# M    47.091932
# Name: Gender, dtype: float64
# Percentage distribution for Education_Level
# Graduate         30.887726
# High School      19.877555
# Unknown          14.999506
# Uneducated       14.683519
# College          10.002962
# Post-Graduate     5.095290
# Doctorate         4.453441
# Name: Education_Level, dtype: float64
# Percentage distribution for Marital_Status
# Married     46.282216
# Single      38.935519
# Unknown      7.396070
# Divorced     7.386195
# Name: Marital_Status, dtype: float64
# Percentage distribution for Income_Category
# Less than $40K    35.163425
# $40K - $60K       17.675521
# $80K - $120K      15.157500
# $60K - $80K       13.844179
# Unknown           10.980547
# $120K +            7.178829
# Name: Income_Category, dtype: float64
# Percentage distribution for Card_Category
# Blue        93.176656
# Silver       5.480399
# Gold         1.145453
# Platinum     0.197492
# Name: Card_Category, dtype: float64

# %%
# Perform analysis on target
df.Attrition_Flag.value_counts().plot(kind='barh')
plt.title(f'Attrition Rate: {round(df.Attrition_Flag.value_counts(normalize=True)[1],2) * 100} %')
plt.show()

# %% [markdown]
# ## Observations:

# %% [markdown]
# ## Bivariate Analysis

# %%
# Calculate the correlation matrix
correlation_matrix = df[numerical_cols].corr()

# Create a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, vmin=-1, vmax=1, cmap='coolwarm', center=0, fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
for col in numerical_cols:
    df.pivot_table(index = 'Attrition_Flag', values = col, aggfunc='mean').plot(kind = 'bar')

# %%
# Define a 100% stacked bar chart
for col in categorical_cols:
    summ = pd.crosstab(df[col], df['Attrition_Flag'], normalize='index')
    summ.plot(kind="bar", stacked=True, figsize=(8, 5))
    plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
    plt.show()

# %% [markdown]
# ## Observations:

# %% [markdown]
# ## Feature Reduction/Engineering Step

# %%
# Columns to drop - Drop the varibales that doesn't seem to provide much of an impact on our target variable

df.drop(columns=['CLIENTNUM' , 'Avg_Open_To_Buy', 'Months_on_book' , 'Marital_Status'], inplace=True)

# %%
df.head()
# Out:
#       Attrition_Flag  Customer_Age Gender  Dependent_count Education_Level  \
# 0  Existing Customer            45      M                3     High School
# 1  Existing Customer            49      F                5        Graduate
# 2  Existing Customer            51      M                3        Graduate
# 3  Existing Customer            40      F                4     High School
# 4  Existing Customer            40      M                3      Uneducated
#
#   Income_Category Card_Category  Total_Relationship_Count  \
# 0     $60K - $80K          Blue                         5
# 1  Less than $40K          Blue                         6
# 2    $80K - $120K          Blue                         4
# 3  Less than $40K          Blue                         3
# 4     $60K - $80K          Blue                         5
#
#    Months_Inactive_12_mon  Contacts_Count_12_mon  Credit_Limit  \
# 0                       1                      3       12691.0
# 1                       1                      2        8256.0
# 2                       1                      0        3418.0
# 3                       4                      1        3313.0
# 4                       1                      0        4716.0
#
#    Total_Revolving_Bal  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 0                  777                 1.335             1144              42
# 1                  864                 1.541             1291              33
# 2                    0                 2.594             1887              20
# 3                 2517                 1.405             1171              20
# 4                    0                 2.175              816              28
#
#    Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0                1.625                  0.061
# 1                3.714                  0.105
# 2                2.333                  0.000
# 3                2.333                  0.760
# 4                2.500                  0.000

# %%
# Convert education level to be a little less granular with higher education [post grad onwards] having more impact and lower education

df.Education_Level = df.Education_Level.apply(lambda x: 'Higher ed' if x in ['Post-Graduate', 'Doctorate'] else 'Lower ed')

# %%
## We will encode the target variable to 1 and 0 where 1 represents the people who have churned.
df.Attrition_Flag = df.Attrition_Flag.apply(lambda x: 0 if x == "Existing Customer" else 1)
df.head()
# Out:
#    Attrition_Flag  Customer_Age Gender  Dependent_count Education_Level  \
# 0               0            45      M                3        Lower ed
# 1               0            49      F                5        Lower ed
# 2               0            51      M                3        Lower ed
# 3               0            40      F                4        Lower ed
# 4               0            40      M                3        Lower ed
#
#   Income_Category Card_Category  Total_Relationship_Count  \
# 0     $60K - $80K          Blue                         5
# 1  Less than $40K          Blue                         6
# 2    $80K - $120K          Blue                         4
# 3  Less than $40K          Blue                         3
# 4     $60K - $80K          Blue                         5
#
#    Months_Inactive_12_mon  Contacts_Count_12_mon  Credit_Limit  \
# 0                       1                      3       12691.0
# 1                       1                      2        8256.0
# 2                       1                      0        3418.0
# 3                       4                      1        3313.0
# 4                       1                      0        4716.0
#
#    Total_Revolving_Bal  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 0                  777                 1.335             1144              42
# 1                  864                 1.541             1291              33
# 2                    0                 2.594             1887              20
# 3                 2517                 1.405             1171              20
# 4                    0                 2.175              816              28
#
#    Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0                1.625                  0.061
# 1                3.714                  0.105
# 2                2.333                  0.000
# 3                2.333                  0.760
# 4                2.500                  0.000

# %% [markdown]
# ## Data Preprocessing

# %%
# Remove the columns already dropped from the data
categorical_cols.remove('Marital_Status')

# apply the one hot label encoding
df=pd.get_dummies(df, columns=categorical_cols, drop_first=True)

df.head()

## HW: Additional exercise: Segregate which columns can be label encode and perform label encoding of them instead of one hot encoding
# Out:
#    Attrition_Flag  Customer_Age  Dependent_count  Total_Relationship_Count  \
# 0               0            45                3                         5
# 1               0            49                5                         6
# 2               0            51                3                         4
# 3               0            40                4                         3
# 4               0            40                3                         5
#
#    Months_Inactive_12_mon  Contacts_Count_12_mon  Credit_Limit  \
# 0                       1                      3       12691.0
# 1                       1                      2        8256.0
# 2                       1                      0        3418.0
# 3                       4                      1        3313.0
# 4                       1                      0        4716.0
#
#    Total_Revolving_Bal  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  ...  Gender_M  \
# 0                  777                 1.335             1144  ...         1
# 1                  864                 1.541             1291  ...         0
# 2                    0                 2.594             1887  ...         1
# 3                 2517                 1.405             1171  ...         0
# 4                    0                 2.175              816  ...         1
#
#    Education_Level_Lower ed  Income_Category_$40K - $60K  \
# 0                         1                            0
# 1                         1                            0
# 2                         1                            0
# 3                         1                            0
# 4                         1                            0
#
#    Income_Category_$60K - $80K  Income_Category_$80K - $120K  \
# 0                            1                             0
# 1                            0                             0
# 2                            0                             1
# 3                            0                             0
# 4                            1                             0
#
#    Income_Category_Less than $40K  Income_Category_Unknown  \
# 0                               0                        0
# 1                               1                        0
# 2                               0                        0
# 3                               1                        0
# 4                               0                        0
#
#    Card_Category_Gold  Card_Category_Platinum  Card_Category_Silver
# 0                   0                       0                     0
# 1                   0                       0                     0
# 2                   0                       0                     0
# 3                   0                       0                     0
# 4                   0                       0                     0
#
# [5 rows x 23 columns]

# %% [markdown]
# #### Additional Exercise: Treat the outliers using IQR Rule specially on rfm attributes

# %% [markdown]
# ## Train Test Split

# %%
# specifying the independent and dependent set of variables
X = df.drop(["Attrition_Flag"], axis=1)
Y = df["Attrition_Flag"]

# splitting data in train and test sets
# A good rule of thumb is 70% data in train set and 30% data in test set
# Explaint the stratification here
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.30, stratify=Y, random_state=1
)

# %%
# Analyze the output from train and test data
print(f"Shape of Training set : {X_train.shape}")
print(f"Shape of test set : {X_test.shape}")

print("Percentage of classes in training set:")
print(y_train.value_counts(normalize=True))

print("Percentage of classes in test set:")
print(y_test.value_counts(normalize=True))
# Out:
# Shape of Training set : (7088, 22)
# Shape of test set : (3039, 22)
# Percentage of classes in training set:
# 0    0.839306
# 1    0.160694
# Name: Attrition_Flag, dtype: float64
# Percentage of classes in test set:
# 0    0.839421
# 1    0.160579
# Name: Attrition_Flag, dtype: float64

# %% [markdown]
# ## Model Fitting and evaluation
#
# Choose the appropriate criteria (metric) before you move on with model fitting.
#
#     a. Accuracy
#     b. Precision
#     c. Recall
#     d. F1 Score
#
# Ans. Recall: Bank would be interested in loss of opportunity cases and wouldn't want the customers to leave. Therefore, we will be more interested in recall score.

# %%
# Fit random forest

rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)

rf_model.score(X_train, y_train) # Calculate the accuracy on train set
# Out:
# 1.0

# %%
rf_model.score(X_test, y_test)
# Out:
# 0.9585389930898321

# %%
print(classification_report(y_train, rf_model.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5949
#            1       1.00      1.00      1.00      1139
#
#     accuracy                           1.00      7088
#    macro avg       1.00      1.00      1.00      7088
# weighted avg       1.00      1.00      1.00      7088

# %%
print(classification_report(y_test, rf_model.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      2551
#            1       0.93      0.80      0.86       488
#
#     accuracy                           0.96      3039
#    macro avg       0.95      0.90      0.92      3039
# weighted avg       0.96      0.96      0.96      3039

# %%
# Fit Gradient boosting

gb_model = GradientBoostingClassifier()
gb_model.fit(X_train, y_train)

gb_model.score(X_train, y_train) # Calculate the accuracy on train set
# Out:
# 0.9747460496613995

# %%
gb_model.score(X_test, y_test)
# Out:
# 0.9674234945705824

# %%
print(classification_report(y_train, gb_model.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      5949
#            1       0.96      0.88      0.92      1139
#
#     accuracy                           0.97      7088
#    macro avg       0.97      0.94      0.95      7088
# weighted avg       0.97      0.97      0.97      7088

# %%
print(classification_report(y_test, gb_model.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      2551
#            1       0.93      0.86      0.90       488
#
#     accuracy                           0.97      3039
#    macro avg       0.95      0.93      0.94      3039
# weighted avg       0.97      0.97      0.97      3039

# %% [markdown]
# #### Since we have very low amount of data (and even lower amount of interesting cases), we will restrict our search of model with over sampling.
#
# #### Additional Exercise: Try performing undersampling using imblearn library

# %% [markdown]
# #### Over sampling with random forest and gradient boosting

# %%
sm = SMOTE(sampling_strategy=1, k_neighbors=5, random_state=1)  # Synthetic Minority Over Sampling Technique
X_train_over, y_train_over = sm.fit_resample(X_train, y_train)

# Print out the frequency of target before and after over sampling
print("Before Oversampling, counts of label 'Yes': {}".format(sum(y_train == 1)))
print("Before Oversampling, counts of label 'No': {} \n".format(sum(y_train == 0)))

print("After Oversampling, counts of label 'Yes': {}".format(sum(y_train_over == 1)))
print("After Oversampling, counts of label 'No': {} \n".format(sum(y_train_over == 0)))


print("After Oversampling, the shape of train_X: {}".format(X_train_over.shape))
print("After Oversampling, the shape of train_y: {} \n".format(y_train_over.shape))
# Out:
# Before Oversampling, counts of label 'Yes': 1139
# Before Oversampling, counts of label 'No': 5949
#
# After Oversampling, counts of label 'Yes': 5949
# After Oversampling, counts of label 'No': 5949
#
# After Oversampling, the shape of train_X: (11898, 22)
# After Oversampling, the shape of train_y: (11898,)

# %%
rf_model_over = RandomForestClassifier()
rf_model_over.fit(X_train_over, y_train_over)

rf_model_over.score(X_train_over, y_train_over) # Calculate the accuracy on train set
# Out:
# 1.0

# %%
print(classification_report(y_train_over, rf_model_over.predict(X_train_over)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5949
#            1       1.00      1.00      1.00      5949
#
#     accuracy                           1.00     11898
#    macro avg       1.00      1.00      1.00     11898
# weighted avg       1.00      1.00      1.00     11898

# %%
print(classification_report(y_test, rf_model_over.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97      2551
#            1       0.86      0.87      0.87       488
#
#     accuracy                           0.96      3039
#    macro avg       0.92      0.92      0.92      3039
# weighted avg       0.96      0.96      0.96      3039

# %%
gb_model_over = GradientBoostingClassifier()
gb_model_over.fit(X_train_over, y_train_over)

gb_model_over.score(X_train_over, y_train_over) # Calculate the accuracy on train set
# Out:
# 0.9747856782652546

# %%
print(classification_report(y_train_over, gb_model_over.predict(X_train_over)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97      5949
#            1       0.97      0.98      0.97      5949
#
#     accuracy                           0.97     11898
#    macro avg       0.97      0.97      0.97     11898
# weighted avg       0.97      0.97      0.97     11898

# %%
print(classification_report(y_test, gb_model_over.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97      2551
#            1       0.82      0.93      0.87       488
#
#     accuracy                           0.95      3039
#    macro avg       0.90      0.94      0.92      3039
# weighted avg       0.96      0.95      0.96      3039

# %% [markdown]
# ## Hyperparameter Tuning using Randomized Search [Repeated Experiments]
#
# Possible Combinations:
#
#     1. Raw Random forest
#     2. Raw Gradient boosting
#     3. Random Forest with over sampled data
#     4. Gradient Boosting with over sampled data

# %% [markdown]
# ### Random Forest Parameters:
#
# **n_estimators**: The number of trees in the forest (default: 100)
#
# **max_depth**: The maximum depth of the tree. If None, then nodes are expanded until all leaves are pure or until all leaves contain less than min_samples_split samples (default: None).
#
# **max_features{“sqrt”, “log2”, int, None}**: The number of features to consider when looking for the best split (default: sqrt).

# %%
from sklearn import metrics
# Choose the type of classifier.
rf_tuned0 = RandomForestClassifier(random_state=1)

# Grid of parameters to choose from
parameters = {
                'max_depth':[4, 6, 8, 10, None],
                'max_features': ['sqrt','log2',None],
                'n_estimators': [80, 90, 100, 110, 120]
}

scorer = metrics.make_scorer(metrics.recall_score)

# Run the grid search
random_obj = RandomizedSearchCV(rf_tuned0, parameters, scoring=scorer, cv=3, n_iter = 50, verbose = 2)
random_obj = random_obj.fit(X_train, y_train)

# Set the clf to the best combination of parameters
rf_tuned0 = random_obj.best_estimator_

# Fit the best algorithm to the data.
rf_tuned0.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV] END ...max_depth=6, max_features=sqrt, n_estimators=110; total time=   0.4s
# [CV] END ...max_depth=6, max_features=sqrt, n_estimators=110; total time=   0.4s
# [CV] END ...max_depth=6, max_features=sqrt, n_estimators=110; total time=   0.5s
# [CV] END ...max_depth=8, max_features=sqrt, n_estimators=100; total time=   0.4s
# [CV] END ...max_depth=8, max_features=sqrt, n_estimators=100; total time=   0.3s
# [CV] END ...max_depth=8, max_features=sqrt, n_estimators=100; total time=   0.5s
# [CV] END .max_depth=None, max_features=log2, n_estimators=90; total time=   0.5s
# [CV] END .max_depth=None, max_features=log2, n_estimators=90; total time=   0.5s
# [CV] END .max_depth=None, max_features=log2, n_estimators=90; total time=   0.6s
# [CV] END ...max_depth=8, max_features=None, n_estimators=100; total time=   2.0s
# [CV] END ...max_depth=8, max_features=None, n_estimators=100; total time=   1.9s
# [CV] END ...max_depth=8, max_features=None, n_estimators=100; total time=   1.9s
# [CV] END ...max_depth=4, max_features=log2, n_estimators=110; total time=   0.3s
# [CV] END ...max_depth=4, max_features=log2, n_estimators=110; total time=   0.3s
# [CV] END ...max_depth=4, max_features=log2, n_estimators=110; total time=   0.3s
# [CV] END ....max_depth=6, max_features=sqrt, n_estimators=80; total time=   0.2s
# [CV] END ....max_depth=6, max_features=sqrt, n_estimators=80; total time=   0.3s
# [CV] END ....max_depth=6, max_features=sqrt, n_estimators=80; total time=   0.3s
# [CV] END ...max_depth=8, max_features=sqrt, n_estimators=120; total time=   0.7s
# [CV] END ...max_depth=8, max_features=sqrt, n_estimators=120; total time=   0.7s
# [CV] END ...max_depth=8, max_features=sqrt, n_estimators=120; total time=   0.6s
# [CV] END ....max_depth=6, max_features=log2, n_estimators=90; total time=   0.3s
# [CV] END ....max_depth=6, max_features=log2, n_estimators=90; total time=   0.3s
# [CV] END ....max_depth=6, max_features=log2, n_estimators=90; total time=   0.4s
# [CV] END max_depth=None, max_features=None, n_estimators=120; total time=   2.6s
# [CV] END max_depth=None, max_features=None, n_estimators=120; total time=   2.9s
# [CV] END max_depth=None, max_features=None, n_estimators=120; total time=   2.3s
# [CV] END ....max_depth=8, max_features=log2, n_estimators=90; total time=   0.5s
# [CV] END ....max_depth=8, max_features=log2, n_estimators=90; total time=   0.4s
# [CV] END ....max_depth=8, max_features=log2, n_estimators=90; total time=   0.6s
# [CV] END ...max_depth=6, max_features=log2, n_estimators=120; total time=   0.6s
# [CV] END ...max_depth=6, max_features=log2, n_estimators=120; total time=   0.6s
# [CV] END ...max_depth=6, max_features=log2, n_estimators=120; total time=   0.5s
# [CV] END ....max_depth=6, max_features=None, n_estimators=90; total time=   1.3s
# [CV] END ....max_depth=6, max_features=None, n_estimators=90; total time=   1.2s
# [CV] END ....max_depth=6, max_features=None, n_estimators=90; total time=   1.6s
# [CV] END ...max_depth=8, max_features=None, n_estimators=120; total time=   2.7s
# [CV] END ...max_depth=8, max_features=None, n_estimators=120; total time=   2.8s
# [CV] END ...max_depth=8, max_features=None, n_estimators=120; total time=   2.3s
# [CV] END ...max_depth=4, max_features=sqrt, n_estimators=110; total time=   0.3s
# [CV] END ...max_depth=4, max_features=sqrt, n_estimators=110; total time=   0.4s
# [CV] END ...max_depth=4, max_features=sqrt, n_estimators=110; total time=   0.4s
# [CV] END ...max_depth=6, max_features=log2, n_estimators=110; total time=   0.5s
# [CV] END ...max_depth=6, max_features=log2, n_estimators=110; total time=   0.4s
# [CV] END ...max_depth=6, max_features=log2, n_estimators=110; total time=   0.4s
# [CV] END ..max_depth=10, max_features=None, n_estimators=120; total time=   2.5s
# [CV] END ..max_depth=10, max_features=None, n_estimators=120; total time=   2.4s
# [CV] END ..max_depth=10, max_features=None, n_estimators=120; total time=   2.4s
# [CV] END ...max_depth=8, max_features=log2, n_estimators=110; total time=   0.6s
# [CV] END ...max_depth=8, max_features=log2, n_estimators=110; total time=   0.6s
# [CV] END ...max_depth=8, max_features=log2, n_estimators=110; total time=   0.5s
# [CV] END ...max_depth=4, max_features=None, n_estimators=110; total time=   1.3s
# [CV] END ...max_depth=4, max_features=None, n_estimators=110; total time=   1.4s
# [CV] END ...max_depth=4, max_features=None, n_estimators=110; total time=   1.5s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=110; total time=   0.8s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=110; total time=   0.7s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=110; total time=   0.6s
# [CV] END ...max_depth=6, max_features=None, n_estimators=120; total time=   1.8s
# [CV] END ...max_depth=6, max_features=None, n_estimators=120; total time=   1.8s
# [CV] END ...max_depth=6, max_features=None, n_estimators=120; total time=   1.8s
# [CV] END max_depth=None, max_features=log2, n_estimators=100; total time=   0.8s
# [CV] END max_depth=None, max_features=log2, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, max_features=log2, n_estimators=100; total time=   0.5s
# [CV] END ..max_depth=10, max_features=None, n_estimators=110; total time=   2.2s
# [CV] END ..max_depth=10, max_features=None, n_estimators=110; total time=   2.5s
# [CV] END ..max_depth=10, max_features=None, n_estimators=110; total time=   2.1s
# [CV] END ...max_depth=10, max_features=sqrt, n_estimators=90; total time=   0.5s
# [CV] END ...max_depth=10, max_features=sqrt, n_estimators=90; total time=   0.5s
# [CV] END ...max_depth=10, max_features=sqrt, n_estimators=90; total time=   0.6s
# [CV] END max_depth=None, max_features=log2, n_estimators=120; total time=   0.9s
# [CV] END max_depth=None, max_features=log2, n_estimators=120; total time=   1.0s
# [CV] END max_depth=None, max_features=log2, n_estimators=120; total time=   1.0s
# [CV] END ...max_depth=4, max_features=log2, n_estimators=100; total time=   0.4s
# [CV] END ...max_depth=4, max_features=log2, n_estimators=100; total time=   0.4s
# [CV] END ...max_depth=4, max_features=log2, n_estimators=100; total time=   0.4s
# [CV] END ...max_depth=6, max_features=None, n_estimators=100; total time=   1.7s
# [CV] END ...max_depth=6, max_features=None, n_estimators=100; total time=   1.5s
# [CV] END ...max_depth=6, max_features=None, n_estimators=100; total time=   1.6s
# [CV] END ...max_depth=6, max_features=sqrt, n_estimators=120; total time=   0.5s
# [CV] END ...max_depth=6, max_features=sqrt, n_estimators=120; total time=   0.5s
# [CV] END ...max_depth=6, max_features=sqrt, n_estimators=120; total time=   0.4s
# [CV] END ....max_depth=4, max_features=None, n_estimators=80; total time=   0.7s
# [CV] END ....max_depth=4, max_features=None, n_estimators=80; total time=   0.7s
# [CV] END ....max_depth=4, max_features=None, n_estimators=80; total time=   0.8s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=110; total time=   0.6s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=110; total time=   0.6s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=110; total time=   0.6s
# [CV] END ....max_depth=6, max_features=None, n_estimators=80; total time=   1.1s
# [CV] END ....max_depth=6, max_features=None, n_estimators=80; total time=   1.1s
# [CV] END ....max_depth=6, max_features=None, n_estimators=80; total time=   1.1s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=100; total time=   0.5s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=100; total time=   0.5s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=100; total time=   0.4s
# [CV] END ...max_depth=10, max_features=log2, n_estimators=90; total time=   0.4s
# [CV] END ...max_depth=10, max_features=log2, n_estimators=90; total time=   0.4s
# [CV] END ...max_depth=10, max_features=log2, n_estimators=90; total time=   0.4s
# [CV] END .max_depth=None, max_features=sqrt, n_estimators=80; total time=   0.4s
# [CV] END .max_depth=None, max_features=sqrt, n_estimators=80; total time=   0.5s
# [CV] END .max_depth=None, max_features=sqrt, n_estimators=80; total time=   0.4s
# [CV] END .max_depth=None, max_features=None, n_estimators=80; total time=   1.4s
# [CV] END .max_depth=None, max_features=None, n_estimators=80; total time=   1.6s
# [CV] END .max_depth=None, max_features=None, n_estimators=80; total time=   1.5s
# [CV] END ....max_depth=8, max_features=sqrt, n_estimators=90; total time=   0.4s
# [CV] END ....max_depth=8, max_features=sqrt, n_estimators=90; total time=   0.4s
# [CV] END ....max_depth=8, max_features=sqrt, n_estimators=90; total time=   0.4s
# [CV] END ....max_depth=6, max_features=log2, n_estimators=80; total time=   0.3s
# [CV] END ....max_depth=6, max_features=log2, n_estimators=80; total time=   0.3s
# [CV] END ....max_depth=6, max_features=log2, n_estimators=80; total time=   0.3s
# [CV] END ...max_depth=10, max_features=log2, n_estimators=80; total time=   0.4s
# [CV] END ...max_depth=10, max_features=log2, n_estimators=80; total time=   0.4s
# [CV] END ...max_depth=10, max_features=log2, n_estimators=80; total time=   0.4s
# [CV] END ....max_depth=8, max_features=None, n_estimators=90; total time=   1.7s
# [CV] END ....max_depth=8, max_features=None, n_estimators=90; total time=   1.6s
# [CV] END ....max_depth=8, max_features=None, n_estimators=90; total time=   1.5s
# [CV] END .max_depth=None, max_features=None, n_estimators=90; total time=   1.8s
# [CV] END .max_depth=None, max_features=None, n_estimators=90; total time=   2.2s
# [CV] END .max_depth=None, max_features=None, n_estimators=90; total time=   1.8s
# [CV] END ...max_depth=4, max_features=None, n_estimators=120; total time=   1.5s
# [CV] END ...max_depth=4, max_features=None, n_estimators=120; total time=   1.5s
# [CV] END ...max_depth=4, max_features=None, n_estimators=120; total time=   1.3s
# [CV] END max_depth=None, max_features=log2, n_estimators=110; total time=   0.7s
# [CV] END max_depth=None, max_features=log2, n_estimators=110; total time=   0.7s
# [CV] END max_depth=None, max_features=log2, n_estimators=110; total time=   0.6s
# [CV] END ..max_depth=10, max_features=None, n_estimators=100; total time=   2.0s
# [CV] END ..max_depth=10, max_features=None, n_estimators=100; total time=   2.0s
# [CV] END ..max_depth=10, max_features=None, n_estimators=100; total time=   1.8s
# [CV] END .max_depth=None, max_features=log2, n_estimators=80; total time=   0.5s
# [CV] END .max_depth=None, max_features=log2, n_estimators=80; total time=   0.6s
# [CV] END .max_depth=None, max_features=log2, n_estimators=80; total time=   0.5s
# [CV] END ...max_depth=6, max_features=None, n_estimators=110; total time=   2.2s
# [CV] END ...max_depth=6, max_features=None, n_estimators=110; total time=   1.9s
# [CV] END ...max_depth=6, max_features=None, n_estimators=110; total time=   1.6s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=100; total time=   0.6s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=100; total time=   0.6s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=100; total time=   0.5s
# [CV] END ...max_depth=8, max_features=log2, n_estimators=120; total time=   0.6s
# [CV] END ...max_depth=8, max_features=log2, n_estimators=120; total time=   0.8s
# [CV] END ...max_depth=8, max_features=log2, n_estimators=120; total time=   0.6s
# [CV] END max_depth=None, max_features=None, n_estimators=100; total time=   2.5s
# [CV] END max_depth=None, max_features=None, n_estimators=100; total time=   2.3s
# [CV] END max_depth=None, max_features=None, n_estimators=100; total time=   2.1s
# [CV] END ....max_depth=8, max_features=log2, n_estimators=80; total time=   0.4s
# [CV] END ....max_depth=8, max_features=log2, n_estimators=80; total time=   0.4s
# [CV] END ....max_depth=8, max_features=log2, n_estimators=80; total time=   0.4s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=120; total time=   0.8s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=120; total time=   0.9s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=120; total time=   0.7s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=120; total time=   0.7s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=120; total time=   0.6s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=120; total time=   0.6s
# RandomForestClassifier(max_depth=10, max_features=None, n_estimators=120,
#                        random_state=1)

# %%
print(classification_report(y_train, rf_tuned0.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      5949
#            1       0.99      0.97      0.98      1139
#
#     accuracy                           0.99      7088
#    macro avg       0.99      0.98      0.99      7088
# weighted avg       0.99      0.99      0.99      7088

# %%
print(classification_report(y_test, rf_tuned0.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      2551
#            1       0.89      0.87      0.88       488
#
#     accuracy                           0.96      3039
#    macro avg       0.93      0.92      0.93      3039
# weighted avg       0.96      0.96      0.96      3039

# %% [markdown]
# ### Gradient Boosting Parameters:
#
# **n_estimators**: The number of boosting stages to perform. Gradient boosting is fairly robust to over-fitting so a large number usually results in better performance. Values must be in the range [1, inf) (default: 100).
#
# **max_depth**: Maximum depth of the individual regression estimators. The maximum depth limits the number of nodes in the tree. Tune this parameter for best performance; the best value depends on the interaction of the input variables. If None, then nodes are expanded until all leaves are pure or until all leaves contain less than min_samples_split samples. If int, values must be in the range [1, inf) (default: 3).
#
# **max_features{“sqrt”, “log2”, int, None}**: The number of features to consider when looking for the best split (default: None).
#
# **learning_rate**: Learning rate shrinks the contribution of each tree by learning_rate. There is a trade-off between learning_rate and n_estimators. Values must be in the range [0.0, inf) (default: 0.1).
#
# **subsample**: The fraction of samples to be used for fitting the individual base learners. If smaller than 1.0 this results in Stochastic Gradient Boosting. subsample interacts with the parameter n_estimators. Choosing subsample < 1.0 leads to a reduction of variance and an increase in bias. Values must be in the range (0.0, 1.0] (default: 1).

# %%
# Choose the type of classifier.
gb_tuned0 = GradientBoostingClassifier(random_state=1)

# Grid of parameters to choose from
parameters = {'n_estimators': np.arange(50,200,25),
              'learning_rate': np.arange(0.001, 0.1, 0.001),
              'subsample':[0.7,0.8,0.9,1],
              'max_features':[0.7,0.8,0.9,1],
              'max_depth':[3,5,7,10]
              }

scorer = metrics.make_scorer(metrics.recall_score)

# Run the grid search
random_obj = RandomizedSearchCV(gb_tuned0, parameters, scoring=scorer, cv=3, n_iter = 50, verbose = 2)
random_obj = random_obj.fit(X_train, y_train)

# Set the clf to the best combination of parameters
gb_tuned0 = random_obj.best_estimator_

# Fit the best algorithm to the data.
gb_tuned0.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV] END learning_rate=0.077, max_depth=3, max_features=0.7, n_estimators=50, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.077, max_depth=3, max_features=0.7, n_estimators=50, subsample=0.7; total time=   0.2s
# [CV] END learning_rate=0.077, max_depth=3, max_features=0.7, n_estimators=50, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.008, max_depth=3, max_features=1, n_estimators=150, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.008, max_depth=3, max_features=1, n_estimators=150, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.008, max_depth=3, max_features=1, n_estimators=150, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.051000000000000004, max_depth=5, max_features=0.9, n_estimators=125, subsample=0.9; total time=   2.1s
# [CV] END learning_rate=0.051000000000000004, max_depth=5, max_features=0.9, n_estimators=125, subsample=0.9; total time=   1.6s
# [CV] END learning_rate=0.051000000000000004, max_depth=5, max_features=0.9, n_estimators=125, subsample=0.9; total time=   1.8s
# [CV] END learning_rate=0.049, max_depth=10, max_features=0.8, n_estimators=50, subsample=0.8; total time=   1.5s
# [CV] END learning_rate=0.049, max_depth=10, max_features=0.8, n_estimators=50, subsample=0.8; total time=   1.7s
# [CV] END learning_rate=0.049, max_depth=10, max_features=0.8, n_estimators=50, subsample=0.8; total time=   1.5s
# [CV] END learning_rate=0.029, max_depth=3, max_features=0.7, n_estimators=75, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.029, max_depth=3, max_features=0.7, n_estimators=75, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.029, max_depth=3, max_features=0.7, n_estimators=75, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.077, max_depth=7, max_features=0.7, n_estimators=100, subsample=0.8; total time=   1.7s
# [CV] END learning_rate=0.077, max_depth=7, max_features=0.7, n_estimators=100, subsample=0.8; total time=   1.7s
# [CV] END learning_rate=0.077, max_depth=7, max_features=0.7, n_estimators=100, subsample=0.8; total time=   1.9s
# [CV] END learning_rate=0.099, max_depth=10, max_features=0.7, n_estimators=75, subsample=0.9; total time=   2.5s
# [CV] END learning_rate=0.099, max_depth=10, max_features=0.7, n_estimators=75, subsample=0.9; total time=   2.5s
# [CV] END learning_rate=0.099, max_depth=10, max_features=0.7, n_estimators=75, subsample=0.9; total time=   2.5s
# [CV] END learning_rate=0.089, max_depth=7, max_features=1, n_estimators=50, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.089, max_depth=7, max_features=1, n_estimators=50, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.089, max_depth=7, max_features=1, n_estimators=50, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.045, max_depth=7, max_features=0.8, n_estimators=175, subsample=0.9; total time=   3.8s
# [CV] END learning_rate=0.045, max_depth=7, max_features=0.8, n_estimators=175, subsample=0.9; total time=   3.6s
# [CV] END learning_rate=0.045, max_depth=7, max_features=0.8, n_estimators=175, subsample=0.9; total time=   3.8s
# [CV] END learning_rate=0.033, max_depth=5, max_features=0.8, n_estimators=150, subsample=0.9; total time=   2.4s
# [CV] END learning_rate=0.033, max_depth=5, max_features=0.8, n_estimators=150, subsample=0.9; total time=   2.8s
# [CV] END learning_rate=0.033, max_depth=5, max_features=0.8, n_estimators=150, subsample=0.9; total time=   2.1s
# [CV] END learning_rate=0.025, max_depth=10, max_features=0.7, n_estimators=75, subsample=0.7; total time=   2.2s
# [CV] END learning_rate=0.025, max_depth=10, max_features=0.7, n_estimators=75, subsample=0.7; total time=   2.2s
# [CV] END learning_rate=0.025, max_depth=10, max_features=0.7, n_estimators=75, subsample=0.7; total time=   2.3s
# [CV] END learning_rate=0.028, max_depth=10, max_features=0.7, n_estimators=50, subsample=0.7; total time=   1.6s
# [CV] END learning_rate=0.028, max_depth=10, max_features=0.7, n_estimators=50, subsample=0.7; total time=   1.5s
# [CV] END learning_rate=0.028, max_depth=10, max_features=0.7, n_estimators=50, subsample=0.7; total time=   1.3s
# [CV] END learning_rate=0.067, max_depth=3, max_features=1, n_estimators=175, subsample=1; total time=   0.3s
# [CV] END learning_rate=0.067, max_depth=3, max_features=1, n_estimators=175, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.067, max_depth=3, max_features=1, n_estimators=175, subsample=1; total time=   0.2s
# [CV] END learning_rate=0.014000000000000002, max_depth=7, max_features=0.7, n_estimators=175, subsample=1; total time=   3.8s
# [CV] END learning_rate=0.014000000000000002, max_depth=7, max_features=0.7, n_estimators=175, subsample=1; total time=   3.6s
# [CV] END learning_rate=0.014000000000000002, max_depth=7, max_features=0.7, n_estimators=175, subsample=1; total time=   3.9s
# [CV] END learning_rate=0.064, max_depth=7, max_features=0.8, n_estimators=125, subsample=0.9; total time=   2.7s
# [CV] END learning_rate=0.064, max_depth=7, max_features=0.8, n_estimators=125, subsample=0.9; total time=   3.2s
# [CV] END learning_rate=0.064, max_depth=7, max_features=0.8, n_estimators=125, subsample=0.9; total time=   2.6s
# [CV] END learning_rate=0.041, max_depth=3, max_features=1, n_estimators=125, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.041, max_depth=3, max_features=1, n_estimators=125, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.041, max_depth=3, max_features=1, n_estimators=125, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.082, max_depth=5, max_features=1, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.082, max_depth=5, max_features=1, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.082, max_depth=5, max_features=1, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END learning_rate=0.017, max_depth=5, max_features=0.9, n_estimators=100, subsample=0.7; total time=   1.3s
# [CV] END learning_rate=0.017, max_depth=5, max_features=0.9, n_estimators=100, subsample=0.7; total time=   1.4s
# [CV] END learning_rate=0.017, max_depth=5, max_features=0.9, n_estimators=100, subsample=0.7; total time=   1.4s
# [CV] END learning_rate=0.057, max_depth=10, max_features=1, n_estimators=50, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.057, max_depth=10, max_features=1, n_estimators=50, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.057, max_depth=10, max_features=1, n_estimators=50, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.036000000000000004, max_depth=10, max_features=0.8, n_estimators=100, subsample=0.8; total time=   3.2s
# [CV] END learning_rate=0.036000000000000004, max_depth=10, max_features=0.8, n_estimators=100, subsample=0.8; total time=   3.0s
# [CV] END learning_rate=0.036000000000000004, max_depth=10, max_features=0.8, n_estimators=100, subsample=0.8; total time=   2.9s
# [CV] END learning_rate=0.005, max_depth=5, max_features=1, n_estimators=100, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.005, max_depth=5, max_features=1, n_estimators=100, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.005, max_depth=5, max_features=1, n_estimators=100, subsample=0.9; total time=   0.2s
# [CV] END learning_rate=0.027000000000000003, max_depth=10, max_features=0.7, n_estimators=50, subsample=0.8; total time=   1.3s
# [CV] END learning_rate=0.027000000000000003, max_depth=10, max_features=0.7, n_estimators=50, subsample=0.8; total time=   1.3s
# [CV] END learning_rate=0.027000000000000003, max_depth=10, max_features=0.7, n_estimators=50, subsample=0.8; total time=   1.4s
# [CV] END learning_rate=0.098, max_depth=7, max_features=0.7, n_estimators=75, subsample=0.8; total time=   1.2s
# [CV] END learning_rate=0.098, max_depth=7, max_features=0.7, n_estimators=75, subsample=0.8; total time=   1.3s
# [CV] END learning_rate=0.098, max_depth=7, max_features=0.7, n_estimators=75, subsample=0.8; total time=   1.2s
# [CV] END learning_rate=0.082, max_depth=10, max_features=0.9, n_estimators=75, subsample=1; total time=   3.0s
# [CV] END learning_rate=0.082, max_depth=10, max_features=0.9, n_estimators=75, subsample=1; total time=   2.9s
# [CV] END learning_rate=0.082, max_depth=10, max_features=0.9, n_estimators=75, subsample=1; total time=   3.0s
# [CV] END learning_rate=0.091, max_depth=7, max_features=0.7, n_estimators=125, subsample=1; total time=   2.7s
# [CV] END learning_rate=0.091, max_depth=7, max_features=0.7, n_estimators=125, subsample=1; total time=   2.4s
# [CV] END learning_rate=0.091, max_depth=7, max_features=0.7, n_estimators=125, subsample=1; total time=   2.5s
# [CV] END learning_rate=0.085, max_depth=10, max_features=1, n_estimators=125, subsample=0.7; total time=   1.5s
# [CV] END learning_rate=0.085, max_depth=10, max_features=1, n_estimators=125, subsample=0.7; total time=   1.7s
# [CV] END learning_rate=0.085, max_depth=10, max_features=1, n_estimators=125, subsample=0.7; total time=   1.9s
# [CV] END learning_rate=0.095, max_depth=5, max_features=1, n_estimators=150, subsample=0.9; total time=   0.5s
# [CV] END learning_rate=0.095, max_depth=5, max_features=1, n_estimators=150, subsample=0.9; total time=   0.6s
# [CV] END learning_rate=0.095, max_depth=5, max_features=1, n_estimators=150, subsample=0.9; total time=   0.6s
# [CV] END learning_rate=0.043000000000000003, max_depth=7, max_features=1, n_estimators=125, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.043000000000000003, max_depth=7, max_features=1, n_estimators=125, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.043000000000000003, max_depth=7, max_features=1, n_estimators=125, subsample=0.8; total time=   0.8s
# [CV] END learning_rate=0.048, max_depth=10, max_features=0.8, n_estimators=150, subsample=1; total time=   7.0s
# [CV] END learning_rate=0.048, max_depth=10, max_features=0.8, n_estimators=150, subsample=1; total time=   6.8s
# [CV] END learning_rate=0.048, max_depth=10, max_features=0.8, n_estimators=150, subsample=1; total time=   6.4s
# [CV] END learning_rate=0.042, max_depth=5, max_features=0.9, n_estimators=175, subsample=0.8; total time=   2.7s
# [CV] END learning_rate=0.042, max_depth=5, max_features=0.9, n_estimators=175, subsample=0.8; total time=   2.7s
# [CV] END learning_rate=0.042, max_depth=5, max_features=0.9, n_estimators=175, subsample=0.8; total time=   2.7s
# [CV] END learning_rate=0.025, max_depth=10, max_features=0.7, n_estimators=50, subsample=0.8; total time=   1.3s
# [CV] END learning_rate=0.025, max_depth=10, max_features=0.7, n_estimators=50, subsample=0.8; total time=   1.7s
# [CV] END learning_rate=0.025, max_depth=10, max_features=0.7, n_estimators=50, subsample=0.8; total time=   1.8s
# [CV] END learning_rate=0.07100000000000001, max_depth=10, max_features=1, n_estimators=100, subsample=0.7; total time=   1.4s
# [CV] END learning_rate=0.07100000000000001, max_depth=10, max_features=1, n_estimators=100, subsample=0.7; total time=   1.6s
# [CV] END learning_rate=0.07100000000000001, max_depth=10, max_features=1, n_estimators=100, subsample=0.7; total time=   1.5s
# [CV] END learning_rate=0.092, max_depth=10, max_features=1, n_estimators=150, subsample=0.7; total time=   2.1s
# [CV] END learning_rate=0.092, max_depth=10, max_features=1, n_estimators=150, subsample=0.7; total time=   2.1s
# [CV] END learning_rate=0.092, max_depth=10, max_features=1, n_estimators=150, subsample=0.7; total time=   1.9s
# [CV] END learning_rate=0.055, max_depth=7, max_features=0.9, n_estimators=175, subsample=0.9; total time=   3.7s
# [CV] END learning_rate=0.055, max_depth=7, max_features=0.9, n_estimators=175, subsample=0.9; total time=   4.0s
# [CV] END learning_rate=0.055, max_depth=7, max_features=0.9, n_estimators=175, subsample=0.9; total time=   4.3s
# [CV] END learning_rate=0.043000000000000003, max_depth=3, max_features=1, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.043000000000000003, max_depth=3, max_features=1, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.043000000000000003, max_depth=3, max_features=1, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.039, max_depth=5, max_features=1, n_estimators=125, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.039, max_depth=5, max_features=1, n_estimators=125, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.039, max_depth=5, max_features=1, n_estimators=125, subsample=0.8; total time=   0.4s
# [CV] END learning_rate=0.078, max_depth=3, max_features=0.8, n_estimators=75, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.078, max_depth=3, max_features=0.8, n_estimators=75, subsample=1; total time=   0.6s
# [CV] END learning_rate=0.078, max_depth=3, max_features=0.8, n_estimators=75, subsample=1; total time=   0.6s
# [CV] END learning_rate=0.07, max_depth=3, max_features=0.8, n_estimators=175, subsample=1; total time=   1.5s
# [CV] END learning_rate=0.07, max_depth=3, max_features=0.8, n_estimators=175, subsample=1; total time=   1.6s
# [CV] END learning_rate=0.07, max_depth=3, max_features=0.8, n_estimators=175, subsample=1; total time=   1.5s
# [CV] END learning_rate=0.039, max_depth=10, max_features=1, n_estimators=125, subsample=1; total time=   2.2s
# [CV] END learning_rate=0.039, max_depth=10, max_features=1, n_estimators=125, subsample=1; total time=   2.4s
# [CV] END learning_rate=0.039, max_depth=10, max_features=1, n_estimators=125, subsample=1; total time=   1.9s
# [CV] END learning_rate=0.085, max_depth=7, max_features=0.7, n_estimators=125, subsample=0.9; total time=   2.4s
# [CV] END learning_rate=0.085, max_depth=7, max_features=0.7, n_estimators=125, subsample=0.9; total time=   2.3s
# [CV] END learning_rate=0.085, max_depth=7, max_features=0.7, n_estimators=125, subsample=0.9; total time=   2.2s
# [CV] END learning_rate=0.077, max_depth=7, max_features=1, n_estimators=150, subsample=0.9; total time=   0.7s
# [CV] END learning_rate=0.077, max_depth=7, max_features=1, n_estimators=150, subsample=0.9; total time=   0.6s
# [CV] END learning_rate=0.077, max_depth=7, max_features=1, n_estimators=150, subsample=0.9; total time=   0.7s
# [CV] END learning_rate=0.037000000000000005, max_depth=10, max_features=1, n_estimators=125, subsample=0.7; total time=   1.6s
# [CV] END learning_rate=0.037000000000000005, max_depth=10, max_features=1, n_estimators=125, subsample=0.7; total time=   1.7s
# [CV] END learning_rate=0.037000000000000005, max_depth=10, max_features=1, n_estimators=125, subsample=0.7; total time=   1.8s
# [CV] END learning_rate=0.091, max_depth=3, max_features=0.9, n_estimators=75, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.091, max_depth=3, max_features=0.9, n_estimators=75, subsample=1; total time=   0.8s
# [CV] END learning_rate=0.091, max_depth=3, max_features=0.9, n_estimators=75, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.015, max_depth=5, max_features=0.7, n_estimators=150, subsample=1; total time=   2.1s
# [CV] END learning_rate=0.015, max_depth=5, max_features=0.7, n_estimators=150, subsample=1; total time=   2.2s
# [CV] END learning_rate=0.015, max_depth=5, max_features=0.7, n_estimators=150, subsample=1; total time=   2.1s
# [CV] END learning_rate=0.016, max_depth=5, max_features=1, n_estimators=175, subsample=0.9; total time=   0.5s
# [CV] END learning_rate=0.016, max_depth=5, max_features=1, n_estimators=175, subsample=0.9; total time=   0.5s
# [CV] END learning_rate=0.016, max_depth=5, max_features=1, n_estimators=175, subsample=0.9; total time=   0.5s
# [CV] END learning_rate=0.085, max_depth=10, max_features=1, n_estimators=150, subsample=1; total time=   2.3s
# [CV] END learning_rate=0.085, max_depth=10, max_features=1, n_estimators=150, subsample=1; total time=   2.1s
# [CV] END learning_rate=0.085, max_depth=10, max_features=1, n_estimators=150, subsample=1; total time=   2.6s
# [CV] END learning_rate=0.038, max_depth=7, max_features=1, n_estimators=175, subsample=0.9; total time=   1.4s
# [CV] END learning_rate=0.038, max_depth=7, max_features=1, n_estimators=175, subsample=0.9; total time=   0.9s
# [CV] END learning_rate=0.038, max_depth=7, max_features=1, n_estimators=175, subsample=0.9; total time=   0.9s
# [CV] END learning_rate=0.08600000000000001, max_depth=10, max_features=0.9, n_estimators=50, subsample=0.9; total time=   1.7s
# [CV] END learning_rate=0.08600000000000001, max_depth=10, max_features=0.9, n_estimators=50, subsample=0.9; total time=   2.3s
# [CV] END learning_rate=0.08600000000000001, max_depth=10, max_features=0.9, n_estimators=50, subsample=0.9; total time=   2.7s
# [CV] END learning_rate=0.057, max_depth=3, max_features=0.8, n_estimators=100, subsample=0.8; total time=   1.1s
# [CV] END learning_rate=0.057, max_depth=3, max_features=0.8, n_estimators=100, subsample=0.8; total time=   1.0s
# [CV] END learning_rate=0.057, max_depth=3, max_features=0.8, n_estimators=100, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.081, max_depth=7, max_features=1, n_estimators=50, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.081, max_depth=7, max_features=1, n_estimators=50, subsample=0.8; total time=   0.2s
# [CV] END learning_rate=0.081, max_depth=7, max_features=1, n_estimators=50, subsample=0.8; total time=   0.2s
# GradientBoostingClassifier(learning_rate=0.098, max_depth=7, max_features=0.7,
#                            n_estimators=75, random_state=1, subsample=0.8)

# %%
print(classification_report(y_train, gb_tuned0.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5949
#            1       1.00      1.00      1.00      1139
#
#     accuracy                           1.00      7088
#    macro avg       1.00      1.00      1.00      7088
# weighted avg       1.00      1.00      1.00      7088

# %%
print(classification_report(y_test, gb_tuned0.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      2551
#            1       0.92      0.89      0.90       488
#
#     accuracy                           0.97      3039
#    macro avg       0.95      0.94      0.94      3039
# weighted avg       0.97      0.97      0.97      3039

# %%
from sklearn import metrics

# Choose the type of classifier.
rf_tuned = RandomForestClassifier(random_state=1)

# Grid of parameters to choose from
parameters = {
                'max_depth':[4, 6, 8, 10, None],
                'max_features': ['sqrt','log2',None],
                'n_estimators': [80, 90, 100, 110, 120]
}

scorer = metrics.make_scorer(metrics.recall_score)

# Run the grid search
random_obj = RandomizedSearchCV(rf_tuned, parameters, scoring=scorer, cv=3, n_iter = 50, verbose = 2)
random_obj = random_obj.fit(X_train_over, y_train_over)

# Set the clf to the best combination of parameters
rf_tuned = random_obj.best_estimator_

# Fit the best algorithm to the data.
rf_tuned.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV] END ....max_depth=6, max_features=None, n_estimators=90; total time=   1.5s
# [CV] END ....max_depth=6, max_features=None, n_estimators=90; total time=   1.7s
# [CV] END ....max_depth=6, max_features=None, n_estimators=90; total time=   1.6s
# [CV] END ..max_depth=10, max_features=None, n_estimators=120; total time=   3.2s
# [CV] END ..max_depth=10, max_features=None, n_estimators=120; total time=   3.8s
# [CV] END ..max_depth=10, max_features=None, n_estimators=120; total time=   3.0s
# [CV] END ...max_depth=6, max_features=sqrt, n_estimators=120; total time=   0.6s
# [CV] END ...max_depth=6, max_features=sqrt, n_estimators=120; total time=   0.6s
# [CV] END ...max_depth=6, max_features=sqrt, n_estimators=120; total time=   0.6s
# [CV] END ...max_depth=10, max_features=sqrt, n_estimators=90; total time=   0.6s
# [CV] END ...max_depth=10, max_features=sqrt, n_estimators=90; total time=   0.7s
# [CV] END ...max_depth=10, max_features=sqrt, n_estimators=90; total time=   0.7s
# [CV] END ....max_depth=8, max_features=sqrt, n_estimators=80; total time=   0.4s
# [CV] END ....max_depth=8, max_features=sqrt, n_estimators=80; total time=   0.5s
# [CV] END ....max_depth=8, max_features=sqrt, n_estimators=80; total time=   0.5s
# [CV] END ...max_depth=8, max_features=None, n_estimators=100; total time=   2.4s
# [CV] END ...max_depth=8, max_features=None, n_estimators=100; total time=   2.4s
# [CV] END ...max_depth=8, max_features=None, n_estimators=100; total time=   2.3s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, max_features=None, n_estimators=110; total time=   2.9s
# [CV] END max_depth=None, max_features=None, n_estimators=110; total time=   3.1s
# [CV] END max_depth=None, max_features=None, n_estimators=110; total time=   3.7s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=110; total time=   0.7s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=110; total time=   1.0s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=110; total time=   1.0s
# [CV] END ...max_depth=4, max_features=sqrt, n_estimators=100; total time=   0.5s
# [CV] END ...max_depth=4, max_features=sqrt, n_estimators=100; total time=   0.5s
# [CV] END ...max_depth=4, max_features=sqrt, n_estimators=100; total time=   0.4s
# [CV] END ...max_depth=4, max_features=sqrt, n_estimators=110; total time=   0.3s
# [CV] END ...max_depth=4, max_features=sqrt, n_estimators=110; total time=   0.4s
# [CV] END ...max_depth=4, max_features=sqrt, n_estimators=110; total time=   0.4s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=120; total time=   0.8s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=120; total time=   0.9s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=120; total time=   0.8s
# [CV] END ....max_depth=4, max_features=sqrt, n_estimators=80; total time=   0.3s
# [CV] END ....max_depth=4, max_features=sqrt, n_estimators=80; total time=   0.3s
# [CV] END ....max_depth=4, max_features=sqrt, n_estimators=80; total time=   0.4s
# [CV] END ...max_depth=8, max_features=sqrt, n_estimators=120; total time=   0.9s
# [CV] END ...max_depth=8, max_features=sqrt, n_estimators=120; total time=   1.0s
# [CV] END ...max_depth=8, max_features=sqrt, n_estimators=120; total time=   0.9s
# [CV] END ...max_depth=6, max_features=sqrt, n_estimators=100; total time=   0.6s
# [CV] END ...max_depth=6, max_features=sqrt, n_estimators=100; total time=   0.6s
# [CV] END ...max_depth=6, max_features=sqrt, n_estimators=100; total time=   0.4s
# [CV] END .max_depth=None, max_features=None, n_estimators=80; total time=   2.7s
# [CV] END .max_depth=None, max_features=None, n_estimators=80; total time=   2.7s
# [CV] END .max_depth=None, max_features=None, n_estimators=80; total time=   2.9s
# [CV] END ...max_depth=4, max_features=log2, n_estimators=120; total time=   0.4s
# [CV] END ...max_depth=4, max_features=log2, n_estimators=120; total time=   0.4s
# [CV] END ...max_depth=4, max_features=log2, n_estimators=120; total time=   0.4s
# [CV] END ...max_depth=8, max_features=log2, n_estimators=120; total time=   0.7s
# [CV] END ...max_depth=8, max_features=log2, n_estimators=120; total time=   0.6s
# [CV] END ...max_depth=8, max_features=log2, n_estimators=120; total time=   0.7s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=100; total time=   0.6s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=100; total time=   0.7s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=100; total time=   0.8s
# [CV] END ....max_depth=8, max_features=None, n_estimators=80; total time=   1.9s
# [CV] END ....max_depth=8, max_features=None, n_estimators=80; total time=   2.0s
# [CV] END ....max_depth=8, max_features=None, n_estimators=80; total time=   2.1s
# [CV] END max_depth=None, max_features=log2, n_estimators=120; total time=   1.0s
# [CV] END max_depth=None, max_features=log2, n_estimators=120; total time=   1.1s
# [CV] END max_depth=None, max_features=log2, n_estimators=120; total time=   1.1s
# [CV] END ...max_depth=4, max_features=log2, n_estimators=100; total time=   0.3s
# [CV] END ...max_depth=4, max_features=log2, n_estimators=100; total time=   0.3s
# [CV] END ...max_depth=4, max_features=log2, n_estimators=100; total time=   0.3s
# [CV] END ....max_depth=4, max_features=sqrt, n_estimators=90; total time=   0.3s
# [CV] END ....max_depth=4, max_features=sqrt, n_estimators=90; total time=   0.4s
# [CV] END ....max_depth=4, max_features=sqrt, n_estimators=90; total time=   0.3s
# [CV] END ...max_depth=4, max_features=None, n_estimators=110; total time=   1.5s
# [CV] END ...max_depth=4, max_features=None, n_estimators=110; total time=   1.4s
# [CV] END ...max_depth=4, max_features=None, n_estimators=110; total time=   1.4s
# [CV] END ...max_depth=6, max_features=log2, n_estimators=100; total time=   0.4s
# [CV] END ...max_depth=6, max_features=log2, n_estimators=100; total time=   0.5s
# [CV] END ...max_depth=6, max_features=log2, n_estimators=100; total time=   0.5s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=100; total time=   0.6s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=100; total time=   0.6s
# [CV] END ..max_depth=10, max_features=log2, n_estimators=100; total time=   0.7s
# [CV] END ...max_depth=6, max_features=None, n_estimators=120; total time=   2.2s
# [CV] END ...max_depth=6, max_features=None, n_estimators=120; total time=   2.2s
# [CV] END ...max_depth=6, max_features=None, n_estimators=120; total time=   2.2s
# [CV] END ...max_depth=8, max_features=None, n_estimators=110; total time=   2.4s
# [CV] END ...max_depth=8, max_features=None, n_estimators=110; total time=   2.5s
# [CV] END ...max_depth=8, max_features=None, n_estimators=110; total time=   2.5s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=120; total time=   0.9s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=120; total time=   0.8s
# [CV] END max_depth=None, max_features=sqrt, n_estimators=120; total time=   0.9s
# [CV] END ....max_depth=8, max_features=sqrt, n_estimators=90; total time=   0.5s
# [CV] END ....max_depth=8, max_features=sqrt, n_estimators=90; total time=   0.5s
# [CV] END ....max_depth=8, max_features=sqrt, n_estimators=90; total time=   0.5s
# [CV] END ...max_depth=10, max_features=None, n_estimators=80; total time=   1.9s
# [CV] END ...max_depth=10, max_features=None, n_estimators=80; total time=   2.0s
# [CV] END ...max_depth=10, max_features=None, n_estimators=80; total time=   2.0s
# [CV] END max_depth=None, max_features=log2, n_estimators=110; total time=   0.8s
# [CV] END max_depth=None, max_features=log2, n_estimators=110; total time=   0.8s
# [CV] END max_depth=None, max_features=log2, n_estimators=110; total time=   0.8s
# [CV] END ....max_depth=4, max_features=None, n_estimators=90; total time=   1.2s
# [CV] END ....max_depth=4, max_features=None, n_estimators=90; total time=   1.4s
# [CV] END ....max_depth=4, max_features=None, n_estimators=90; total time=   1.2s
# [CV] END ...max_depth=8, max_features=sqrt, n_estimators=110; total time=   0.6s
# [CV] END ...max_depth=8, max_features=sqrt, n_estimators=110; total time=   0.7s
# [CV] END ...max_depth=8, max_features=sqrt, n_estimators=110; total time=   0.6s
# [CV] END .max_depth=None, max_features=sqrt, n_estimators=80; total time=   0.6s
# [CV] END .max_depth=None, max_features=sqrt, n_estimators=80; total time=   0.6s
# [CV] END .max_depth=None, max_features=sqrt, n_estimators=80; total time=   0.6s
# [CV] END ....max_depth=8, max_features=None, n_estimators=90; total time=   1.9s
# [CV] END ....max_depth=8, max_features=None, n_estimators=90; total time=   2.0s
# [CV] END ....max_depth=8, max_features=None, n_estimators=90; total time=   1.9s
# [CV] END ....max_depth=4, max_features=log2, n_estimators=90; total time=   0.3s
# [CV] END ....max_depth=4, max_features=log2, n_estimators=90; total time=   0.2s
# [CV] END ....max_depth=4, max_features=log2, n_estimators=90; total time=   0.2s
# [CV] END ....max_depth=8, max_features=log2, n_estimators=90; total time=   0.5s
# [CV] END ....max_depth=8, max_features=log2, n_estimators=90; total time=   0.4s
# [CV] END ....max_depth=8, max_features=log2, n_estimators=90; total time=   0.6s
# [CV] END ....max_depth=4, max_features=None, n_estimators=80; total time=   1.0s
# [CV] END ....max_depth=4, max_features=None, n_estimators=80; total time=   1.0s
# [CV] END ....max_depth=4, max_features=None, n_estimators=80; total time=   1.0s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=120; total time=   0.8s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=120; total time=   0.8s
# [CV] END ..max_depth=10, max_features=sqrt, n_estimators=120; total time=   0.8s
# [CV] END ...max_depth=10, max_features=sqrt, n_estimators=80; total time=   0.5s
# [CV] END ...max_depth=10, max_features=sqrt, n_estimators=80; total time=   0.5s
# [CV] END ...max_depth=10, max_features=sqrt, n_estimators=80; total time=   0.5s
# [CV] END ...max_depth=8, max_features=None, n_estimators=120; total time=   2.6s
# [CV] END ...max_depth=8, max_features=None, n_estimators=120; total time=   2.7s
# [CV] END ...max_depth=8, max_features=None, n_estimators=120; total time=   2.8s
# [CV] END ...max_depth=4, max_features=None, n_estimators=120; total time=   1.6s
# [CV] END ...max_depth=4, max_features=None, n_estimators=120; total time=   1.6s
# [CV] END ...max_depth=4, max_features=None, n_estimators=120; total time=   1.5s
# [CV] END .max_depth=None, max_features=log2, n_estimators=90; total time=   0.6s
# [CV] END .max_depth=None, max_features=log2, n_estimators=90; total time=   0.6s
# [CV] END .max_depth=None, max_features=log2, n_estimators=90; total time=   0.6s
# [CV] END max_depth=None, max_features=None, n_estimators=120; total time=   3.5s
# [CV] END max_depth=None, max_features=None, n_estimators=120; total time=   3.3s
# [CV] END max_depth=None, max_features=None, n_estimators=120; total time=   3.6s
# [CV] END ..max_depth=10, max_features=None, n_estimators=100; total time=   2.5s
# [CV] END ..max_depth=10, max_features=None, n_estimators=100; total time=   2.7s
# [CV] END ..max_depth=10, max_features=None, n_estimators=100; total time=   2.5s
# [CV] END ...max_depth=6, max_features=log2, n_estimators=110; total time=   0.5s
# [CV] END ...max_depth=6, max_features=log2, n_estimators=110; total time=   0.5s
# [CV] END ...max_depth=6, max_features=log2, n_estimators=110; total time=   0.5s
# [CV] END max_depth=None, max_features=None, n_estimators=100; total time=   2.9s
# [CV] END max_depth=None, max_features=None, n_estimators=100; total time=   2.7s
# [CV] END max_depth=None, max_features=None, n_estimators=100; total time=   2.9s
# [CV] END ...max_depth=8, max_features=log2, n_estimators=110; total time=   0.6s
# [CV] END ...max_depth=8, max_features=log2, n_estimators=110; total time=   0.6s
# [CV] END ...max_depth=8, max_features=log2, n_estimators=110; total time=   0.7s
# [CV] END ....max_depth=8, max_features=log2, n_estimators=80; total time=   0.5s
# [CV] END ....max_depth=8, max_features=log2, n_estimators=80; total time=   0.4s
# [CV] END ....max_depth=8, max_features=log2, n_estimators=80; total time=   0.4s
# RandomForestClassifier(max_features='log2', n_estimators=90, random_state=1)

# %%
print(classification_report(y_train_over, rf_tuned.predict(X_train_over)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      5949
#            1       1.00      0.91      0.96      5949
#
#     accuracy                           0.96     11898
#    macro avg       0.96      0.96      0.96     11898
# weighted avg       0.96      0.96      0.96     11898

# %%
print(classification_report(y_test, rf_tuned.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      2551
#            1       0.93      0.80      0.86       488
#
#     accuracy                           0.96      3039
#    macro avg       0.94      0.89      0.92      3039
# weighted avg       0.96      0.96      0.96      3039

# %%
# Choose the type of classifier.
gb_tuned = GradientBoostingClassifier(random_state=1)

# Grid of parameters to choose from
parameters = {'n_estimators': np.arange(50,200,25),
              'learning_rate': np.arange(0.001, 0.1, 0.001),
              'subsample':[0.7,0.8,0.9,1],
              'max_features':[0.7,0.8,0.9,1],
              'max_depth':[3,5,7,10]
              }

scorer = metrics.make_scorer(metrics.recall_score)

# Run the grid search
random_obj = RandomizedSearchCV(gb_tuned, parameters, scoring=scorer, cv=3, n_iter = 50, verbose = 2)
random_obj = random_obj.fit(X_train_over, y_train_over)

# Set the clf to the best combination of parameters
gb_tuned = random_obj.best_estimator_

# Fit the best algorithm to the data.
gb_tuned.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV] END learning_rate=0.074, max_depth=7, max_features=0.7, n_estimators=125, subsample=0.9; total time=   2.9s
# [CV] END learning_rate=0.074, max_depth=7, max_features=0.7, n_estimators=125, subsample=0.9; total time=   2.9s
# [CV] END learning_rate=0.074, max_depth=7, max_features=0.7, n_estimators=125, subsample=0.9; total time=   2.9s
# [CV] END learning_rate=0.02, max_depth=3, max_features=0.9, n_estimators=75, subsample=0.9; total time=   0.9s
# [CV] END learning_rate=0.02, max_depth=3, max_features=0.9, n_estimators=75, subsample=0.9; total time=   0.9s
# [CV] END learning_rate=0.02, max_depth=3, max_features=0.9, n_estimators=75, subsample=0.9; total time=   0.9s
# [CV] END learning_rate=0.039, max_depth=5, max_features=1, n_estimators=150, subsample=0.8; total time=   0.6s
# [CV] END learning_rate=0.039, max_depth=5, max_features=1, n_estimators=150, subsample=0.8; total time=   0.5s
# [CV] END learning_rate=0.039, max_depth=5, max_features=1, n_estimators=150, subsample=0.8; total time=   0.7s
# [CV] END learning_rate=0.099, max_depth=5, max_features=0.8, n_estimators=100, subsample=0.9; total time=   2.0s
# [CV] END learning_rate=0.099, max_depth=5, max_features=0.8, n_estimators=100, subsample=0.9; total time=   2.1s
# [CV] END learning_rate=0.099, max_depth=5, max_features=0.8, n_estimators=100, subsample=0.9; total time=   2.2s
# [CV] END learning_rate=0.031, max_depth=3, max_features=0.7, n_estimators=50, subsample=0.9; total time=   0.5s
# [CV] END learning_rate=0.031, max_depth=3, max_features=0.7, n_estimators=50, subsample=0.9; total time=   0.4s
# [CV] END learning_rate=0.031, max_depth=3, max_features=0.7, n_estimators=50, subsample=0.9; total time=   0.4s
# [CV] END learning_rate=0.058, max_depth=7, max_features=0.9, n_estimators=175, subsample=0.8; total time=   4.5s
# [CV] END learning_rate=0.058, max_depth=7, max_features=0.9, n_estimators=175, subsample=0.8; total time=   4.8s
# [CV] END learning_rate=0.058, max_depth=7, max_features=0.9, n_estimators=175, subsample=0.8; total time=   4.5s
# [CV] END learning_rate=0.033, max_depth=5, max_features=0.7, n_estimators=175, subsample=1; total time=   3.0s
# [CV] END learning_rate=0.033, max_depth=5, max_features=0.7, n_estimators=175, subsample=1; total time=   3.5s
# [CV] END learning_rate=0.033, max_depth=5, max_features=0.7, n_estimators=175, subsample=1; total time=   2.8s
# [CV] END learning_rate=0.052000000000000005, max_depth=3, max_features=0.9, n_estimators=175, subsample=1; total time=   2.7s
# [CV] END learning_rate=0.052000000000000005, max_depth=3, max_features=0.9, n_estimators=175, subsample=1; total time=   2.4s
# [CV] END learning_rate=0.052000000000000005, max_depth=3, max_features=0.9, n_estimators=175, subsample=1; total time=   2.1s
# [CV] END learning_rate=0.098, max_depth=10, max_features=0.8, n_estimators=175, subsample=1; total time=   8.4s
# [CV] END learning_rate=0.098, max_depth=10, max_features=0.8, n_estimators=175, subsample=1; total time=   8.1s
# [CV] END learning_rate=0.098, max_depth=10, max_features=0.8, n_estimators=175, subsample=1; total time=   8.8s
# [CV] END learning_rate=0.048, max_depth=7, max_features=0.9, n_estimators=75, subsample=0.8; total time=   1.8s
# [CV] END learning_rate=0.048, max_depth=7, max_features=0.9, n_estimators=75, subsample=0.8; total time=   2.0s
# [CV] END learning_rate=0.048, max_depth=7, max_features=0.9, n_estimators=75, subsample=0.8; total time=   2.0s
# [CV] END learning_rate=0.08700000000000001, max_depth=5, max_features=0.8, n_estimators=75, subsample=0.7; total time=   1.3s
# [CV] END learning_rate=0.08700000000000001, max_depth=5, max_features=0.8, n_estimators=75, subsample=0.7; total time=   1.1s
# [CV] END learning_rate=0.08700000000000001, max_depth=5, max_features=0.8, n_estimators=75, subsample=0.7; total time=   1.2s
# [CV] END learning_rate=0.044000000000000004, max_depth=10, max_features=0.8, n_estimators=100, subsample=1; total time=   4.9s
# [CV] END learning_rate=0.044000000000000004, max_depth=10, max_features=0.8, n_estimators=100, subsample=1; total time=   4.9s
# [CV] END learning_rate=0.044000000000000004, max_depth=10, max_features=0.8, n_estimators=100, subsample=1; total time=   4.5s
# [CV] END learning_rate=0.051000000000000004, max_depth=7, max_features=1, n_estimators=125, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.051000000000000004, max_depth=7, max_features=1, n_estimators=125, subsample=0.7; total time=   0.6s
# [CV] END learning_rate=0.051000000000000004, max_depth=7, max_features=1, n_estimators=125, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.092, max_depth=7, max_features=0.9, n_estimators=125, subsample=0.9; total time=   3.5s
# [CV] END learning_rate=0.092, max_depth=7, max_features=0.9, n_estimators=125, subsample=0.9; total time=   3.4s
# [CV] END learning_rate=0.092, max_depth=7, max_features=0.9, n_estimators=125, subsample=0.9; total time=   3.5s
# [CV] END learning_rate=0.054, max_depth=3, max_features=0.8, n_estimators=100, subsample=1; total time=   1.1s
# [CV] END learning_rate=0.054, max_depth=3, max_features=0.8, n_estimators=100, subsample=1; total time=   1.1s
# [CV] END learning_rate=0.054, max_depth=3, max_features=0.8, n_estimators=100, subsample=1; total time=   1.2s
# [CV] END learning_rate=0.089, max_depth=7, max_features=0.7, n_estimators=150, subsample=1; total time=   3.6s
# [CV] END learning_rate=0.089, max_depth=7, max_features=0.7, n_estimators=150, subsample=1; total time=   3.6s
# [CV] END learning_rate=0.089, max_depth=7, max_features=0.7, n_estimators=150, subsample=1; total time=   3.9s
# [CV] END learning_rate=0.030000000000000002, max_depth=3, max_features=1, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.030000000000000002, max_depth=3, max_features=1, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END learning_rate=0.030000000000000002, max_depth=3, max_features=1, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.02, max_depth=7, max_features=0.8, n_estimators=150, subsample=0.9; total time=   4.0s
# [CV] END learning_rate=0.02, max_depth=7, max_features=0.8, n_estimators=150, subsample=0.9; total time=   3.9s
# [CV] END learning_rate=0.02, max_depth=7, max_features=0.8, n_estimators=150, subsample=0.9; total time=   3.9s
# [CV] END learning_rate=0.098, max_depth=5, max_features=1, n_estimators=100, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.098, max_depth=5, max_features=1, n_estimators=100, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.098, max_depth=5, max_features=1, n_estimators=100, subsample=0.7; total time=   0.3s
# [CV] END learning_rate=0.031, max_depth=7, max_features=0.8, n_estimators=175, subsample=0.8; total time=   4.2s
# [CV] END learning_rate=0.031, max_depth=7, max_features=0.8, n_estimators=175, subsample=0.8; total time=   4.2s
# [CV] END learning_rate=0.031, max_depth=7, max_features=0.8, n_estimators=175, subsample=0.8; total time=   4.2s
# [CV] END learning_rate=0.035, max_depth=10, max_features=0.8, n_estimators=50, subsample=0.7; total time=   1.6s
# [CV] END learning_rate=0.035, max_depth=10, max_features=0.8, n_estimators=50, subsample=0.7; total time=   1.7s
# [CV] END learning_rate=0.035, max_depth=10, max_features=0.8, n_estimators=50, subsample=0.7; total time=   1.7s
# [CV] END learning_rate=0.08, max_depth=3, max_features=0.8, n_estimators=125, subsample=0.7; total time=   1.3s
# [CV] END learning_rate=0.08, max_depth=3, max_features=0.8, n_estimators=125, subsample=0.7; total time=   1.5s
# [CV] END learning_rate=0.08, max_depth=3, max_features=0.8, n_estimators=125, subsample=0.7; total time=   1.5s
# [CV] END learning_rate=0.035, max_depth=3, max_features=0.7, n_estimators=175, subsample=0.7; total time=   2.0s
# [CV] END learning_rate=0.035, max_depth=3, max_features=0.7, n_estimators=175, subsample=0.7; total time=   1.8s
# [CV] END learning_rate=0.035, max_depth=3, max_features=0.7, n_estimators=175, subsample=0.7; total time=   1.7s
# [CV] END learning_rate=0.07300000000000001, max_depth=3, max_features=0.9, n_estimators=150, subsample=0.7; total time=   1.7s
# [CV] END learning_rate=0.07300000000000001, max_depth=3, max_features=0.9, n_estimators=150, subsample=0.7; total time=   1.5s
# [CV] END learning_rate=0.07300000000000001, max_depth=3, max_features=0.9, n_estimators=150, subsample=0.7; total time=   1.6s
# [CV] END learning_rate=0.028, max_depth=5, max_features=0.8, n_estimators=100, subsample=1; total time=   2.1s
# [CV] END learning_rate=0.028, max_depth=5, max_features=0.8, n_estimators=100, subsample=1; total time=   2.1s
# [CV] END learning_rate=0.028, max_depth=5, max_features=0.8, n_estimators=100, subsample=1; total time=   2.2s
# [CV] END learning_rate=0.077, max_depth=10, max_features=0.9, n_estimators=50, subsample=1; total time=   2.5s
# [CV] END learning_rate=0.077, max_depth=10, max_features=0.9, n_estimators=50, subsample=1; total time=   2.6s
# [CV] END learning_rate=0.077, max_depth=10, max_features=0.9, n_estimators=50, subsample=1; total time=   2.3s
# [CV] END learning_rate=0.07200000000000001, max_depth=7, max_features=0.7, n_estimators=150, subsample=0.9; total time=   3.4s
# [CV] END learning_rate=0.07200000000000001, max_depth=7, max_features=0.7, n_estimators=150, subsample=0.9; total time=   3.6s
# [CV] END learning_rate=0.07200000000000001, max_depth=7, max_features=0.7, n_estimators=150, subsample=0.9; total time=   4.1s
# [CV] END learning_rate=0.091, max_depth=7, max_features=0.8, n_estimators=75, subsample=0.7; total time=   1.9s
# [CV] END learning_rate=0.091, max_depth=7, max_features=0.8, n_estimators=75, subsample=0.7; total time=   1.8s
# [CV] END learning_rate=0.091, max_depth=7, max_features=0.8, n_estimators=75, subsample=0.7; total time=   1.8s
# [CV] END learning_rate=0.068, max_depth=5, max_features=1, n_estimators=100, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.068, max_depth=5, max_features=1, n_estimators=100, subsample=0.7; total time=   0.4s
# [CV] END learning_rate=0.068, max_depth=5, max_features=1, n_estimators=100, subsample=0.7; total time=   0.5s
# [CV] END learning_rate=0.04, max_depth=5, max_features=0.7, n_estimators=75, subsample=0.8; total time=   1.3s
# [CV] END learning_rate=0.04, max_depth=5, max_features=0.7, n_estimators=75, subsample=0.8; total time=   1.3s
# [CV] END learning_rate=0.04, max_depth=5, max_features=0.7, n_estimators=75, subsample=0.8; total time=   1.4s
# [CV] END learning_rate=0.094, max_depth=7, max_features=0.8, n_estimators=175, subsample=0.7; total time=   4.1s
# [CV] END learning_rate=0.094, max_depth=7, max_features=0.8, n_estimators=175, subsample=0.7; total time=   4.0s
# [CV] END learning_rate=0.094, max_depth=7, max_features=0.8, n_estimators=175, subsample=0.7; total time=   4.2s
# [CV] END learning_rate=0.043000000000000003, max_depth=5, max_features=0.7, n_estimators=175, subsample=1; total time=   3.3s
# [CV] END learning_rate=0.043000000000000003, max_depth=5, max_features=0.7, n_estimators=175, subsample=1; total time=   3.4s
# [CV] END learning_rate=0.043000000000000003, max_depth=5, max_features=0.7, n_estimators=175, subsample=1; total time=   2.9s
# [CV] END learning_rate=0.011, max_depth=5, max_features=0.9, n_estimators=100, subsample=0.8; total time=   1.8s
# [CV] END learning_rate=0.011, max_depth=5, max_features=0.9, n_estimators=100, subsample=0.8; total time=   1.7s
# [CV] END learning_rate=0.011, max_depth=5, max_features=0.9, n_estimators=100, subsample=0.8; total time=   1.6s
# [CV] END learning_rate=0.098, max_depth=3, max_features=0.8, n_estimators=125, subsample=1; total time=   1.5s
# [CV] END learning_rate=0.098, max_depth=3, max_features=0.8, n_estimators=125, subsample=1; total time=   1.4s
# [CV] END learning_rate=0.098, max_depth=3, max_features=0.8, n_estimators=125, subsample=1; total time=   1.4s
# [CV] END learning_rate=0.075, max_depth=10, max_features=0.8, n_estimators=175, subsample=1; total time=   7.8s
# [CV] END learning_rate=0.075, max_depth=10, max_features=0.8, n_estimators=175, subsample=1; total time=   7.8s
# [CV] END learning_rate=0.075, max_depth=10, max_features=0.8, n_estimators=175, subsample=1; total time=   8.1s
# [CV] END learning_rate=0.037000000000000005, max_depth=10, max_features=0.8, n_estimators=125, subsample=0.8; total time=   5.9s
# [CV] END learning_rate=0.037000000000000005, max_depth=10, max_features=0.8, n_estimators=125, subsample=0.8; total time=   6.4s
# [CV] END learning_rate=0.037000000000000005, max_depth=10, max_features=0.8, n_estimators=125, subsample=0.8; total time=   6.6s
# [CV] END learning_rate=0.07300000000000001, max_depth=10, max_features=0.9, n_estimators=125, subsample=0.9; total time=   6.3s
# [CV] END learning_rate=0.07300000000000001, max_depth=10, max_features=0.9, n_estimators=125, subsample=0.9; total time=   6.2s
# [CV] END learning_rate=0.07300000000000001, max_depth=10, max_features=0.9, n_estimators=125, subsample=0.9; total time=   6.6s
# [CV] END learning_rate=0.076, max_depth=7, max_features=0.7, n_estimators=125, subsample=0.8; total time=   2.9s
# [CV] END learning_rate=0.076, max_depth=7, max_features=0.7, n_estimators=125, subsample=0.8; total time=   2.9s
# [CV] END learning_rate=0.076, max_depth=7, max_features=0.7, n_estimators=125, subsample=0.8; total time=   2.9s
# [CV] END learning_rate=0.060000000000000005, max_depth=10, max_features=1, n_estimators=175, subsample=1; total time=   3.4s
# [CV] END learning_rate=0.060000000000000005, max_depth=10, max_features=1, n_estimators=175, subsample=1; total time=   3.2s
# [CV] END learning_rate=0.060000000000000005, max_depth=10, max_features=1, n_estimators=175, subsample=1; total time=   3.3s
# [CV] END learning_rate=0.079, max_depth=7, max_features=0.9, n_estimators=50, subsample=0.8; total time=   1.5s
# [CV] END learning_rate=0.079, max_depth=7, max_features=0.9, n_estimators=50, subsample=0.8; total time=   1.3s
# [CV] END learning_rate=0.079, max_depth=7, max_features=0.9, n_estimators=50, subsample=0.8; total time=   1.2s
# [CV] END learning_rate=0.039, max_depth=10, max_features=0.8, n_estimators=125, subsample=0.9; total time=   5.4s
# [CV] END learning_rate=0.039, max_depth=10, max_features=0.8, n_estimators=125, subsample=0.9; total time=   5.6s
# [CV] END learning_rate=0.039, max_depth=10, max_features=0.8, n_estimators=125, subsample=0.9; total time=   6.8s
# [CV] END learning_rate=0.009000000000000001, max_depth=3, max_features=0.8, n_estimators=150, subsample=0.9; total time=   2.0s
# [CV] END learning_rate=0.009000000000000001, max_depth=3, max_features=0.8, n_estimators=150, subsample=0.9; total time=   2.0s
# [CV] END learning_rate=0.009000000000000001, max_depth=3, max_features=0.8, n_estimators=150, subsample=0.9; total time=   2.0s
# [CV] END learning_rate=0.076, max_depth=10, max_features=0.8, n_estimators=50, subsample=0.9; total time=   2.6s
# [CV] END learning_rate=0.076, max_depth=10, max_features=0.8, n_estimators=50, subsample=0.9; total time=   2.5s
# [CV] END learning_rate=0.076, max_depth=10, max_features=0.8, n_estimators=50, subsample=0.9; total time=   2.2s
# [CV] END learning_rate=0.098, max_depth=10, max_features=0.8, n_estimators=150, subsample=0.8; total time=   6.9s
# [CV] END learning_rate=0.098, max_depth=10, max_features=0.8, n_estimators=150, subsample=0.8; total time=   6.1s
# [CV] END learning_rate=0.098, max_depth=10, max_features=0.8, n_estimators=150, subsample=0.8; total time=   5.6s
# [CV] END learning_rate=0.064, max_depth=3, max_features=0.7, n_estimators=100, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.064, max_depth=3, max_features=0.7, n_estimators=100, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.064, max_depth=3, max_features=0.7, n_estimators=100, subsample=0.7; total time=   0.7s
# [CV] END learning_rate=0.048, max_depth=3, max_features=0.8, n_estimators=100, subsample=0.8; total time=   0.9s
# [CV] END learning_rate=0.048, max_depth=3, max_features=0.8, n_estimators=100, subsample=0.8; total time=   0.9s
# [CV] END learning_rate=0.048, max_depth=3, max_features=0.8, n_estimators=100, subsample=0.8; total time=   0.9s
# [CV] END learning_rate=0.009000000000000001, max_depth=10, max_features=0.7, n_estimators=100, subsample=0.7; total time=   3.1s
# [CV] END learning_rate=0.009000000000000001, max_depth=10, max_features=0.7, n_estimators=100, subsample=0.7; total time=   3.2s
# [CV] END learning_rate=0.009000000000000001, max_depth=10, max_features=0.7, n_estimators=100, subsample=0.7; total time=   3.2s
# [CV] END learning_rate=0.043000000000000003, max_depth=3, max_features=0.8, n_estimators=75, subsample=0.9; total time=   0.7s
# [CV] END learning_rate=0.043000000000000003, max_depth=3, max_features=0.8, n_estimators=75, subsample=0.9; total time=   0.8s
# [CV] END learning_rate=0.043000000000000003, max_depth=3, max_features=0.8, n_estimators=75, subsample=0.9; total time=   0.9s
# [CV] END learning_rate=0.016, max_depth=7, max_features=0.7, n_estimators=150, subsample=0.9; total time=   4.3s
# [CV] END learning_rate=0.016, max_depth=7, max_features=0.7, n_estimators=150, subsample=0.9; total time=   4.0s
# [CV] END learning_rate=0.016, max_depth=7, max_features=0.7, n_estimators=150, subsample=0.9; total time=   3.6s
# [CV] END learning_rate=0.036000000000000004, max_depth=5, max_features=0.7, n_estimators=150, subsample=1; total time=   2.7s
# [CV] END learning_rate=0.036000000000000004, max_depth=5, max_features=0.7, n_estimators=150, subsample=1; total time=   2.7s
# [CV] END learning_rate=0.036000000000000004, max_depth=5, max_features=0.7, n_estimators=150, subsample=1; total time=   2.5s
# GradientBoostingClassifier(learning_rate=0.098, max_depth=10, max_features=0.8,
#                            n_estimators=150, random_state=1, subsample=0.8)

# %%
print(classification_report(y_train_over, gb_tuned.predict(X_train_over)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      5949
#            1       1.00      0.96      0.98      5949
#
#     accuracy                           0.98     11898
#    macro avg       0.98      0.98      0.98     11898
# weighted avg       0.98      0.98      0.98     11898

# %%
print(classification_report(y_test, gb_tuned.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      2551
#            1       0.93      0.89      0.91       488
#
#     accuracy                           0.97      3039
#    macro avg       0.95      0.94      0.95      3039
# weighted avg       0.97      0.97      0.97      3039

# %%
models_train_comp_df = pd.DataFrame(
    [
        [precision_score(y_train, rf_model.predict(X_train)),
         recall_score(y_train, rf_model.predict(X_train)),
        f1_score(y_train, rf_model.predict(X_train))],

        [precision_score(y_train, gb_model.predict(X_train)),
         recall_score(y_train, gb_model.predict(X_train)),
        f1_score(y_train, gb_model.predict(X_train))],

         [precision_score(y_train_over, rf_model_over.predict(X_train_over)),
         recall_score(y_train_over, rf_model_over.predict(X_train_over)),
        f1_score(y_train_over, rf_model_over.predict(X_train_over))],

        [precision_score(y_train_over, gb_model_over.predict(X_train_over)),
         recall_score(y_train_over, gb_model_over.predict(X_train_over)),
        f1_score(y_train_over, gb_model_over.predict(X_train_over))],

        [precision_score(y_train, rf_tuned0.predict(X_train)),
         recall_score(y_train, rf_tuned0.predict(X_train)),
        f1_score(y_train, rf_tuned0.predict(X_train))],

        [precision_score(y_train, gb_tuned0.predict(X_train)),
         recall_score(y_train, gb_tuned0.predict(X_train)),
        f1_score(y_train, gb_tuned0.predict(X_train))],

        [precision_score(y_train_over, rf_tuned.predict(X_train_over)),
         recall_score(y_train_over, rf_tuned.predict(X_train_over)),
        f1_score(y_train_over, rf_tuned.predict(X_train_over))],

        [precision_score(y_train_over, gb_tuned.predict(X_train_over)),
         recall_score(y_train_over, gb_tuned.predict(X_train_over)),
        f1_score(y_train_over, gb_tuned.predict(X_train_over))]
    ]
, columns=['Precision', 'recall', 'f1 score']).T
models_train_comp_df.columns = [
    "RF",
    "GB",
    "RF with oversampling",
    "GB with oversampling",
    "Tuned RF",
    "Tuned GB",
    "Tuned RF with oversampling",
    "Tuned GB with oversampling",
]
print("Training performance comparison:")
models_train_comp_df
# Out:
# Training performance comparison:
#             RF        GB  RF with oversampling  GB with oversampling  \
# Precision  1.0  0.958015                   1.0              0.971300
# recall     1.0  0.881475                   1.0              0.978484
# f1 score   1.0  0.918153                   1.0              0.974879
#
#            Tuned RF  Tuned GB  Tuned RF with oversampling  \
# Precision  0.989228  0.998244                    1.000000
# recall     0.967515  0.998244                    0.914944
# f1 score   0.978251  0.998244                    0.955583
#
#            Tuned GB with oversampling
# Precision                    1.000000
# recall                       0.960329
# f1 score                     0.979763

# %%
models_test_comp_df = pd.DataFrame(
    [
        [precision_score(y_test, rf_model.predict(X_test)),
         recall_score(y_test, rf_model.predict(X_test)),
        f1_score(y_test, rf_model.predict(X_test))],

        [precision_score(y_test, gb_model.predict(X_test)),
         recall_score(y_test, gb_model.predict(X_test)),
        f1_score(y_test, gb_model.predict(X_test))],

         [precision_score(y_test, rf_model_over.predict(X_test)),
         recall_score(y_test, rf_model_over.predict(X_test)),
        f1_score(y_test, rf_model_over.predict(X_test))],

        [precision_score(y_test, gb_model_over.predict(X_test)),
         recall_score(y_test, gb_model_over.predict(X_test)),
        f1_score(y_test, gb_model_over.predict(X_test))],

        [precision_score(y_test, rf_tuned0.predict(X_test)),
         recall_score(y_test, rf_tuned0.predict(X_test)),
        f1_score(y_test, rf_tuned0.predict(X_test))],

        [precision_score(y_test, gb_tuned0.predict(X_test)),
         recall_score(y_test, gb_tuned0.predict(X_test)),
        f1_score(y_test, gb_tuned0.predict(X_test))],

        [precision_score(y_test, rf_tuned.predict(X_test)),
         recall_score(y_test, rf_tuned.predict(X_test)),
        f1_score(y_test, rf_tuned.predict(X_test))],

        [precision_score(y_test, gb_tuned.predict(X_test)),
         recall_score(y_test, gb_tuned.predict(X_test)),
        f1_score(y_test, gb_tuned.predict(X_test))]
    ]
, columns=['Precision', 'recall', 'f1 score']).T
models_test_comp_df.columns = [
    "RF",
    "GB",
    "RF with oversampling",
    "GB with oversampling",
    "Tuned RF",
    "Tuned GB",
    "Tuned RF with oversampling",
    "Tuned GB with oversampling"
]
print("Testing performance comparison:")
models_test_comp_df
# Out:
# Testing performance comparison:
#                  RF        GB  RF with oversampling  GB with oversampling  \
# Precision  0.928910  0.927473              0.860606              0.815081
# recall     0.803279  0.864754              0.872951              0.930328
# f1 score   0.861538  0.895016              0.866734              0.868900
#
#            Tuned RF  Tuned GB  Tuned RF with oversampling  \
# Precision  0.888889  0.921277                    0.926540
# recall     0.868852  0.887295                    0.801230
# f1 score   0.878756  0.903967                    0.859341
#
#            Tuned GB with oversampling
# Precision                    0.931034
# recall                       0.885246
# f1 score                     0.907563

# %% [markdown]
# ## Observations:

# %% [markdown]
# #### Additional Exercise: Expand the research via Grid Search

# %%
# Build a auc roc curve

roc_auc = roc_auc_score(y_train_over, gb_model_over.predict_proba(X_train_over)[:,1]) # Getting the best auc roc score
fpr, tpr, thresholds = roc_curve(y_train_over, gb_model_over.predict_proba(X_train_over)[:,1])
plt.figure(figsize=(8, 5))
plt.plot(fpr, tpr, label=f"Gradient Boosting (area = {round(roc_auc,3) * 100}%)")
plt.plot([0, 1], [0, 1], "g--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.01])
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("Receiver operating characteristic")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# #### Additional Exercise: Manipulate the threshold value

# %% [markdown]
# ## Feature Importances

# %%
importances = gb_model_over.feature_importances_
indices = np.argsort(importances)

# %%
plt.figure(figsize=(12, 5))
plt.title("Feature Importances")
plt.bar(range(len(indices)), importances[indices], align="center")
plt.xticks(range(len(indices)), [X_train_over.columns[i] for i in indices], rotation = 90)
plt.xlabel("Relative Importance")
plt.show()
